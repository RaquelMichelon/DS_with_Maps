# %% [markdown]
# <a href="https://colab.research.google.com/github/RaquelMichelon/DS_with_Maps/blob/main/DS_Project_using_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science with Maps
# ## Learning to plot maps to answer business questions
#
# <img src="https://www.oficinadanet.com.br/imagens/post/27852/google-maps-truques_1400x875_5d8ec1be6e50d.jpg" alt="map draw" width="300"/>
#
# [Airbnb DataSet Source](https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data)

# %%
#import libs

import pandas as pd
import numpy as np
import io
from google.colab import files
import plotly.express as px #graphs
import folium #maps

# %%
#uploaded file -> AB_NYC_2019.csv
file_uploded = files.upload()
# Out:
#      <input type="file" id="files-8fb00bc1-2046-486d-ba02-9b997741d0b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fb00bc1-2046-486d-ba02-9b997741d0b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AB_NYC_2019.csv to AB_NYC_2019.csv

# %%
df = pd.read_csv(io.BytesIO(file_uploded['AB_NYC_2019.csv']))

# %%
#drop null rows
df1 = df.dropna()

# %%
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 5  Entire home/apt    200               3                 74  2019-06-22
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129

# %%
# filter just availables homes

#remove column where availability_365 = 0

df1 = df1.loc[df1['availability_365'] > 0, :]

# %%
#to count by group
cols = ['neighbourhood_group', 'price']
data_plot = df1.loc[:, cols].groupby('neighbourhood_group').max().reset_index() #instead of max, could be min(), sum()...

# %%
#plot a graph

px.bar(data_plot, x= 'neighbourhood_group', y = 'price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2cca02e9-f98a-48f9-a44c-ea868567cb28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cca02e9-f98a-48f9-a44c-ea868567cb28")) {                    Plotly.newPlot(                        "2cca02e9-f98a-48f9-a44c-ea868567cb28",                        [{"alignmentgroup":"True","hovertemplate":"neighbourhood_group=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bronx","Brooklyn","Manhattan","Queens","Staten Island"],"xaxis":"x","y":[800,8000,9999,2600,625],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter" ...

# %% [markdown]
# # Where is located the apartment which has the maximum price by Neighbourhood group?

# %%
#preparing map plot

cols = ['price', 'neighbourhood_group', 'latitude', 'longitude']
data_plot = df1.loc[:, cols].groupby('neighbourhood_group').max().reset_index()

# %%
map = folium.Map()
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_b2eedde49892acf473c12cf4db79bc54 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_b2eedde49892acf473c12cf4db79bc54&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_b2eedde49892acf473c12cf4db79bc54 = L.map(
#         &#x27;map_b2eedde49892acf473c12cf4db79bc54&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_6d6b2cf28e573422ba4f28f9069da120 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_b2eedde49892acf473c12cf4db79bc54);
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data_plot
# Out:
#   neighbourhood_group  price  latitude  longitude
# 0               Bronx    800  40.91306  -73.78158
# 1            Brooklyn   8000  40.73890  -73.85676
# 2           Manhattan   9999  40.87665  -73.90855
# 3              Queens   2600  40.79721  -73.71299
# 4       Staten Island    625  40.64779  -74.06356

# %%
#points inside the map

for index, location_info in data_plot.iterrows():
  folium.Marker([location_info['latitude'], location_info['longitude']],
                popup=location_info['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_b2eedde49892acf473c12cf4db79bc54 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_b2eedde49892acf473c12cf4db79bc54&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_b2eedde49892acf473c12cf4db79bc54 = L.map(
#         &#x27;map_b2eedde49892acf473c12cf4db79bc54&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_6d6b2cf28e573422ba4f28f9069da120 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_b2eedde49892acf473c12cf4db79bc54);
#
#         var marker_7cd38c9725f148dd4ddf153f26fea223 = L.marker(
#             [40.91306, -73.78158],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_b2eedde49892acf473c12cf4db79bc54);
#
#
#             var popup_f230512516a93723e097bb4e4166fc48 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_f5d8ff1ebb7ca0ca7e1e3e4e0174d655 = $(`&lt;div id=&quot;html_f5d8ff1ebb7ca0ca7e1e3e4e0174d655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_f230512516a93723e097bb4e4166fc48.setContent(html_f5d8ff1ebb7ca0ca7e1e3e4e0174d655);
#
#
#             marker_7cd38c9725f148dd4ddf153f26fea223.bindPopup(popup_f230512516a93723e097bb4e4166fc48)
#             ;
#
#
#
#
#         var marker_48969cc5488d928f6f363a653cd91e00 = L.marker(
#             [40.7389, -73.85676],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_b2eedde49892acf473c12cf4db79bc54);
#
#
#             var popup_039b4852745255ee84c8fa0a7ba03c10 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_08cd714b823d32ba5139e4ca3485a858 = $(`&lt;div id=&quot;html_08cd714b823d32ba5139e4ca3485a858&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#                 popup_039b4852745255ee84c8fa0a7ba03c10.setContent(html_08cd714b823d32ba5139e4ca3485a858);
#
#
#             marker_48969cc5488d928f6f363a653cd91e00.bindPopup(popup_039b4852745255ee84c8fa0a7ba03c10)
#             ;
#
#
#
#
#         var marker_648dea313f7f561af9398c6dc37b6780 = L.marker(
#             [40.87665, -73.90855],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_b2eedde49892acf473c12cf4db79bc54);
#
#
#             var popup_7ab9d5a499c1f5223bde71c38075c3d9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_20aa27f622472ab27939d7d97328278c = $(`&lt;div id=&quot;html_20aa27f622472ab27939d7d97328278c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#                 popup_7ab9d5a499c1f5223bde71c38075c3d9.setContent(html_20aa27f622472ab27939d7d97328278c);
#
#
#             marker_648dea313f7f561af9398c6dc37b6780.bindPopup(popup_7ab9d5a499c1f5223bde71c38075c3d9)
#             ;
#
#
#
#
#         var marker_b2a8cb155e598325f610abde39938e58 = L.marker(
#             [40.79721, -73.71299],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_b2eedde49892acf473c12cf4db79bc54);
#
#
#             var popup_935000fcaabb9bc09f831b903e33c528 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_633c4967f6ceb395925316cb69011535 = $(`&lt;div id=&quot;html_633c4967f6ceb395925316cb69011535&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#                 popup_935000fcaabb9bc09f831b903e33c528.setContent(html_633c4967f6ceb395925316cb69011535);
#
#
#             marker_b2a8cb155e598325f610abde39938e58.bindPopup(popup_935000fcaabb9bc09f831b903e33c528)
#             ;
#
#
#
#
#         var marker_c8b9322fe5030a9923f6f740d81185dd = L.marker(
#             [40.64779, -74.06356],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_b2eedde49892acf473c12cf4db79bc54);
#
#
#             var popup_60f2d39c2da950af230cec9ad315c955 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_9416b626f939f47b4948784d7060da05 = $(`&lt;div id=&quot;html_9416b626f939f47b4948784d7060da05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Staten Island&lt;/div&gt;`)[0];
#                 popup_60f2d39c2da950af230cec9ad315c955.setContent(html_9416b626f939f47b4948784d7060da05);
#
#
#             marker_c8b9322fe5030a9923f6f740d81185dd.bindPopup(popup_60f2d39c2da950af230cec9ad315c955)
#             ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Where is located the apartments by its room types?

# %%
#where are located the apartments by its types?

#dataset to plot
cols = ['neighbourhood_group', 'room_type', 'latitude', 'longitude']

# df1.loc[rows, columns]
df1.loc[:, cols]
# Out:
#       neighbourhood_group        room_type  latitude  longitude
# 0                Brooklyn     Private room  40.64749  -73.97237
# 1               Manhattan  Entire home/apt  40.75362  -73.98377
# 3                Brooklyn  Entire home/apt  40.68514  -73.95976
# 5               Manhattan  Entire home/apt  40.74767  -73.97500
# 7               Manhattan     Private room  40.76489  -73.98493
# ...                   ...              ...       ...        ...
# 48782           Manhattan     Private room  40.78099  -73.95366
# 48790              Queens     Private room  40.75104  -73.81459
# 48799       Staten Island     Private room  40.54179  -74.14275
# 48805               Bronx  Entire home/apt  40.80787  -73.92400
# 48852            Brooklyn     Private room  40.69805  -73.92801
#
# [26146 rows x 4 columns]

# %%
# to separate room_types by color 

data_plot = df1.loc[:, cols].sample(100) #to show only 100 rows

# create new column

data_plot.loc[:, 'color'] = 'NA'

# %%
data_plot
# Out:
#       neighbourhood_group        room_type  latitude  longitude color
# 0                Brooklyn     Private room  40.64749  -73.97237    NA
# 1               Manhattan  Entire home/apt  40.75362  -73.98377    NA
# 3                Brooklyn  Entire home/apt  40.68514  -73.95976    NA
# 5               Manhattan  Entire home/apt  40.74767  -73.97500    NA
# 7               Manhattan     Private room  40.76489  -73.98493    NA
# ...                   ...              ...       ...        ...   ...
# 48782           Manhattan     Private room  40.78099  -73.95366    NA
# 48790              Queens     Private room  40.75104  -73.81459    NA
# 48799       Staten Island     Private room  40.54179  -74.14275    NA
# 48805               Bronx  Entire home/apt  40.80787  -73.92400    NA
# 48852            Brooklyn     Private room  40.69805  -73.92801    NA
#
# [26146 rows x 5 columns]

# %%
#sign a color for each room_type
data_plot.loc[data_plot['room_type'] == 'Private room', 'color'] = 'purple'
data_plot.loc[data_plot['room_type'] == 'Entire home/apt', 'color'] = 'darkred'
data_plot.loc[data_plot['room_type'] == 'Shared room', 'color'] = 'darkgreen'
data_plot
# Out:
#       neighbourhood_group        room_type  latitude  longitude      color
# 10378               Bronx     Private room  40.85205  -73.78868     purple
# 15429           Manhattan  Entire home/apt  40.79505  -73.94361    darkred
# 42225               Bronx     Private room  40.83988  -73.78287     purple
# 45122       Staten Island     Private room  40.64535  -74.09255     purple
# 29691            Brooklyn  Entire home/apt  40.65757  -73.96039    darkred
# ...                   ...              ...       ...        ...        ...
# 22419           Manhattan  Entire home/apt  40.76476  -73.99453    darkred
# 41682            Brooklyn  Entire home/apt  40.68757  -73.91183    darkred
# 30895              Queens     Private room  40.74309  -73.82472     purple
# 11646           Manhattan  Entire home/apt  40.80822  -73.94264    darkred
# 37784            Brooklyn      Shared room  40.62827  -74.01078  darkgreen
#
# [100 rows x 5 columns]

# %%
#plot the map

map = folium.Map()

for index, location_info in data_plot.iterrows():
  folium.Marker([location_info['latitude'], 
                 location_info['longitude']],
                 popup=location_info['neighbourhood_group'],
                 icon=folium.Icon(color = location_info['color'])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_f338004e052b14259382f6afb5281aea {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_f338004e052b14259382f6afb5281aea&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_f338004e052b14259382f6afb5281aea = L.map(
#         &#x27;map_f338004e052b14259382f6afb5281aea&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_05bb62d6848ac01bfd2c6d0e59771d61 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_f338004e052b14259382f6afb5281aea);
#
#         var marker_7083a38bdea9ea49c5133873e80eae8e = L.marker(
#             [40.85205, -73.78868],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_f338004e052b14259382f6afb5281aea);
#
#
#
#                 var icon_9a48a020080019b2efa946272d11a91a = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;purple&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_7083a38bdea9ea49c5133873e80eae8e.setIcon(icon_9a48a020080019b2efa946272d11a91a);
#
#
#             var popup_46056fb5dae58ab75ccb32226fd9f8ad = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_b1591f5b1ec5033814bec3889c187150 = $(`&lt;div id=&quot;html_b1591f5b1ec5033814bec3889c187150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_46056fb5dae58ab75ccb32226fd9f8ad.setContent(html_b1591f5b1ec5033814bec3889c187150);
#
#
#             marker_7083a38bdea9ea49c5133873e80eae8e.bindPopup(popup_46056fb5dae58ab75ccb32226fd9f8ad)
#             ;
#
#
#
#
#         var marker_da24dd08b544d815dc75ae0ed307cffe = L.marker(
#             [40.79505, -73.94361],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_f338004e052b14259382f6afb5281aea);
#
#
#
#                 var icon_663307b96fcdd2384d7666e779af012d = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;darkred&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_da24dd08b544d815dc75ae0ed307cffe.setIcon(icon_663307b96fcdd2384d7666e779af012d);
#
#
#             var popup_c84eb693eb2ed3e6151de921bd374696 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_985bc65de3f1534b61ba80273ec426f0 = $(`&lt;div id=&quot;html_985bc65de3f1534b61ba80273ec426f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#                 popup_c84eb693eb2ed3e6151de921bd374696.setContent(html_985bc65de3f1534b61ba80273ec426f0);
#
#
#             marker_da24dd08b544d815dc75ae0ed307cffe.bindPopup(popup_c84eb693eb2ed3e6151de921bd374696)
#             ;
#
#
#
#
#         var marker_83d0a9fa9f1056238b1bfaa41cd0f40e = L.marker(
#             [40.83988, -73.78287],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_f338004e052b14259382f6afb5281aea);
#
#
#
#                 var icon_5155fda69ff8a17cd7d954ea1d8043ee = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;purple&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_83d0a9fa9f1056238b1bfaa41cd0f40e.setIcon(icon_5155fda69ff8a17cd7d954ea1d8043ee);
#
#
#             var popup_f8bd6afb86108e1ee64918cd43d6a52c = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_c91a711088be5e00b8e12a6d4f95e0c7 = $(`&lt;div id=&quot;html_c91a711088be5e00b8e12a6d4f95e0c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_f8bd6afb86108e1ee64918cd43d6a52c.setContent(html_c91a711088be5e00b8e12a6d4f95e0c7);
#
#
#             marker_83d0a9fa9f1056238b1bfaa41cd0f40e.bindPopup(popup_f8bd6afb86108e1ee64918cd43d6a52c)
#             ;
#
#
#
#
#         var marker_96c3f1c677307992765ce81be5982a6d = L.marker(
#             [40.64535, -74.09255],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_f338004e052b14259382f6afb5281aea);
#
#
#
#                 var icon_a66a7aea68ec034df17e59d40f4328be = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;purple&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     }

# %% [markdown]
# # Top 10 apartments with more reviews

# %%
df1.head()
# Out:
#      id                                       name  host_id    host_name  \
# 0  2539         Clean & quiet apt home by the park     2787         John
# 1  2595                      Skylit Midtown Castle     2845     Jennifer
# 3  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 7  5178           Large Furnished Room Near B'way      8967     Shunichi
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn      Kensington  40.64749  -73.97237     Private room
# 1           Manhattan         Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn    Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan     Murray Hill  40.74767  -73.97500  Entire home/apt
# 7           Manhattan  Hell's Kitchen  40.76489  -73.98493     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 3     89               1                270  2019-07-05               4.64
# 5    200               3                 74  2019-06-22               0.59
# 7     79               2                430  2019-06-24               3.47
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 3                               1               194
# 5                               1               129
# 7                               1               220

# %%
data_plot = df1.loc[:, ['number_of_reviews', 'neighbourhood_group', 'latitude', 'longitude']].groupby('neighbourhood_group').head(10)
data_plot = data_plot.sort_values(['neighbourhood_group', 'number_of_reviews'], ascending=[True, False])

map = folium.Map()

for index, location_info in data_plot.iterrows():
  folium.Marker([location_info['latitude'], 
                 location_info['longitude']], location_info['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_fb622fd12ad21f059496375189dda0ae {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_fb622fd12ad21f059496375189dda0ae&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_fb622fd12ad21f059496375189dda0ae = L.map(
#         &#x27;map_fb622fd12ad21f059496375189dda0ae&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_c40b53e78ba0c8524ed2fc0280cf3704 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#         var marker_2c9cfb31173a6c26a70b758da4538fc3 = L.marker(
#             [40.86466, -73.85709],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#
#             var popup_fb692d7f1f50be05c565aa77d046b2e6 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_20b794b307304d8c7d17e3664ee80361 = $(`&lt;div id=&quot;html_20b794b307304d8c7d17e3664ee80361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_fb692d7f1f50be05c565aa77d046b2e6.setContent(html_20b794b307304d8c7d17e3664ee80361);
#
#
#             marker_2c9cfb31173a6c26a70b758da4538fc3.bindPopup(popup_fb692d7f1f50be05c565aa77d046b2e6)
#             ;
#
#
#
#
#         var marker_357eac4fcc8cf79b9479fa2d5f23dd97 = L.marker(
#             [40.82802, -73.92039],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#
#             var popup_aed9be694c43d37bb1358ecd82398939 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_f029802f88684ccb8648829b22f2a8ea = $(`&lt;div id=&quot;html_f029802f88684ccb8648829b22f2a8ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_aed9be694c43d37bb1358ecd82398939.setContent(html_f029802f88684ccb8648829b22f2a8ea);
#
#
#             marker_357eac4fcc8cf79b9479fa2d5f23dd97.bindPopup(popup_aed9be694c43d37bb1358ecd82398939)
#             ;
#
#
#
#
#         var marker_204356c20377c4c24fd5e434c77f4d1e = L.marker(
#             [40.83001, -73.92158],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#
#             var popup_1303b4436175371a11f1e47bbe9a99f7 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_a2b4675a88ca1bcb000cda95bc03b41e = $(`&lt;div id=&quot;html_a2b4675a88ca1bcb000cda95bc03b41e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_1303b4436175371a11f1e47bbe9a99f7.setContent(html_a2b4675a88ca1bcb000cda95bc03b41e);
#
#
#             marker_204356c20377c4c24fd5e434c77f4d1e.bindPopup(popup_1303b4436175371a11f1e47bbe9a99f7)
#             ;
#
#
#
#
#         var marker_37b42e42703093fdadb1aaed5d56575a = L.marker(
#             [40.83232, -73.93184],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#
#             var popup_62dad833f6c3c301c53bdb16e6f8f098 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_aa31ada597a752b659e64e1e11cd424e = $(`&lt;div id=&quot;html_aa31ada597a752b659e64e1e11cd424e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_62dad833f6c3c301c53bdb16e6f8f098.setContent(html_aa31ada597a752b659e64e1e11cd424e);
#
#
#             marker_37b42e42703093fdadb1aaed5d56575a.bindPopup(popup_62dad833f6c3c301c53bdb16e6f8f098)
#             ;
#
#
#
#
#         var marker_915c41343db25bf7da85f31718e1287d = L.marker(
#             [40.89747, -73.8639],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#
#             var popup_c2e15c940e50d462c214b3f101b7f8fa = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_92e722f8a8c1981da9227a9fab7d7310 = $(`&lt;div id=&quot;html_92e722f8a8c1981da9227a9fab7d7310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_c2e15c940e50d462c214b3f101b7f8fa.setContent(html_92e722f8a8c1981da9227a9fab7d7310);
#
#
#             marker_915c41343db25bf7da85f31718e1287d.bindPopup(popup_c2e15c940e50d462c214b3f101b7f8fa)
#             ;
#
#
#
#
#         var marker_14b8e1a6d3ed28f2d6c66c7778fefd22 = L.marker(
#             [40.83075, -73.93058],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_fb622fd12ad21f059496375189dda0ae);
#
#
#             var popup_180a3bb4c65ea4324d4ab1651e230676 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 v

# %% [markdown]
# # Top 50 prices

# %%
data_plot = df1.loc[:, ['name', 'price', 'latitude', 'longitude']].sort_values(['price'], ascending=[False]).head(50)

map = folium.Map()

for index, location_info in data_plot.iterrows():
  folium.Marker([location_info['latitude'], 
                 location_info['longitude']], location_info['name']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_88206b6a12e83a12eb92670fbb86e16d {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_88206b6a12e83a12eb92670fbb86e16d&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_88206b6a12e83a12eb92670fbb86e16d = L.map(
#         &#x27;map_88206b6a12e83a12eb92670fbb86e16d&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_2eff26f1e09652d2d01165a46188da06 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#         var marker_4eb93de29fcffbf4e047b76ddd6bcced = L.marker(
#             [40.71355, -73.98507],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#
#             var popup_91d697d301b0fa26d226db0a472ad399 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_5aaec945fcb7cc6772c85b7532e7487d = $(`&lt;div id=&quot;html_5aaec945fcb7cc6772c85b7532e7487d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quiet, Clean, Lit @ LES &amp; Chinatown&lt;/div&gt;`)[0];
#                 popup_91d697d301b0fa26d226db0a472ad399.setContent(html_5aaec945fcb7cc6772c85b7532e7487d);
#
#
#             marker_4eb93de29fcffbf4e047b76ddd6bcced.bindPopup(popup_91d697d301b0fa26d226db0a472ad399)
#             ;
#
#
#
#
#         var marker_7a5a6839a98ca70a33aaf8cf1247e538 = L.marker(
#             [40.72197, -74.00633],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#
#             var popup_8f6f4c125ea66887628e3b169802c109 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_c819da7fea8e982724923b19ec93f20b = $(`&lt;div id=&quot;html_c819da7fea8e982724923b19ec93f20b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho&lt;/div&gt;`)[0];
#                 popup_8f6f4c125ea66887628e3b169802c109.setContent(html_c819da7fea8e982724923b19ec93f20b);
#
#
#             marker_7a5a6839a98ca70a33aaf8cf1247e538.bindPopup(popup_8f6f4c125ea66887628e3b169802c109)
#             ;
#
#
#
#
#         var marker_8e8a06af5af23a7a2869c4b3f8e0e761 = L.marker(
#             [40.69137, -73.96723],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#
#             var popup_2ce711bc0fefeebbbdd0ebcbd94810b7 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_72557259e7ac7f921af3b85fc2e17e81 = $(`&lt;div id=&quot;html_72557259e7ac7f921af3b85fc2e17e81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Film Location&lt;/div&gt;`)[0];
#                 popup_2ce711bc0fefeebbbdd0ebcbd94810b7.setContent(html_72557259e7ac7f921af3b85fc2e17e81);
#
#
#             marker_8e8a06af5af23a7a2869c4b3f8e0e761.bindPopup(popup_2ce711bc0fefeebbbdd0ebcbd94810b7)
#             ;
#
#
#
#
#         var marker_76c13ad3fcf4ba1377024d794ca6bf39 = L.marker(
#             [40.65724, -73.9245],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#
#             var popup_13b2b975286837651ea0f72de082d193 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_e08c4c0a87e8d2e4f14f7deb935b5b1f = $(`&lt;div id=&quot;html_e08c4c0a87e8d2e4f14f7deb935b5b1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gem of east Flatbush&lt;/div&gt;`)[0];
#                 popup_13b2b975286837651ea0f72de082d193.setContent(html_e08c4c0a87e8d2e4f14f7deb935b5b1f);
#
#
#             marker_76c13ad3fcf4ba1377024d794ca6bf39.bindPopup(popup_13b2b975286837651ea0f72de082d193)
#             ;
#
#
#
#
#         var marker_72d4f3f66d04cb708ca697e6b1479a05 = L.marker(
#             [40.77782, -73.97848],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#
#             var popup_c8959e5b31def3d49857b52f715682b9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_c750724a94fc56e73d6e7020f7e870fb = $(`&lt;div id=&quot;html_c750724a94fc56e73d6e7020f7e870fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UWS 1BR w/backyard + block from CP&lt;/div&gt;`)[0];
#                 popup_c8959e5b31def3d49857b52f715682b9.setContent(html_c750724a94fc56e73d6e7020f7e870fb);
#
#
#             marker_72d4f3f66d04cb708ca697e6b1479a05.bindPopup(popup_c8959e5b31def3d49857b52f715682b9)
#             ;
#
#
#
#
#         var marker_0863a346d7473bba12936cd783e04d28 = L.marker(
#             [40.74482, -73.98367],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_88206b6a12e83a12eb92670fbb86e16d);
#
#
#             var popup_b

# %% [markdown]
# # Top 10 lowest price by region

# %%
data_plot = df1.loc[:, ['number_of_reviews', 'neighbourhood_group', 'latitude', 'longitude']].groupby('neighbourhood_group').tail(10)
data_plot = data_plot.sort_values(['neighbourhood_group', 'number_of_reviews'], ascending=[True, False])

map = folium.Map()

for index, location_info in data_plot.iterrows():
  folium.Marker([location_info['latitude'], 
                 location_info['longitude']], location_info['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_300dfb7a9003102dfe663e6fefa9cc65 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_300dfb7a9003102dfe663e6fefa9cc65&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_300dfb7a9003102dfe663e6fefa9cc65 = L.map(
#         &#x27;map_300dfb7a9003102dfe663e6fefa9cc65&#x27;, {
#         center: [0, 0],
#         zoom: 1,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_5fa57f67d26e35ccaddd7bd810088bcb = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#         var marker_f8e9114e195a6f9b5b66268f9558976e = L.marker(
#             [40.86143, -73.84556],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#
#             var popup_aafe7bc3059c6cce4924b4c2e91e33d2 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_2ae2e7aae7a0f67f155e8bac96c16465 = $(`&lt;div id=&quot;html_2ae2e7aae7a0f67f155e8bac96c16465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_aafe7bc3059c6cce4924b4c2e91e33d2.setContent(html_2ae2e7aae7a0f67f155e8bac96c16465);
#
#
#             marker_f8e9114e195a6f9b5b66268f9558976e.bindPopup(popup_aafe7bc3059c6cce4924b4c2e91e33d2)
#             ;
#
#
#
#
#         var marker_5faef36fd27e3922c4b25b8a37fa1808 = L.marker(
#             [40.85247, -73.86418],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#
#             var popup_a597a21b613ab22fe70e47ee33150511 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_64953847c567e74b22e0c86d1f1b2da5 = $(`&lt;div id=&quot;html_64953847c567e74b22e0c86d1f1b2da5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_a597a21b613ab22fe70e47ee33150511.setContent(html_64953847c567e74b22e0c86d1f1b2da5);
#
#
#             marker_5faef36fd27e3922c4b25b8a37fa1808.bindPopup(popup_a597a21b613ab22fe70e47ee33150511)
#             ;
#
#
#
#
#         var marker_236fbfbd2537c8ba078202b3d8c7d51d = L.marker(
#             [40.80787, -73.924],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#
#             var popup_163c6ec233b81e7860632d3c903f1619 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_7cf09f96627647848ded8be38df81f89 = $(`&lt;div id=&quot;html_7cf09f96627647848ded8be38df81f89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_163c6ec233b81e7860632d3c903f1619.setContent(html_7cf09f96627647848ded8be38df81f89);
#
#
#             marker_236fbfbd2537c8ba078202b3d8c7d51d.bindPopup(popup_163c6ec233b81e7860632d3c903f1619)
#             ;
#
#
#
#
#         var marker_909c0eccf89da9c9e89ed82133489eef = L.marker(
#             [40.91234, -73.89417],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#
#             var popup_47422d8271d1a48280c22f040ab925bc = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_6e5abf917f41ad79a7971ebcf2d81850 = $(`&lt;div id=&quot;html_6e5abf917f41ad79a7971ebcf2d81850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_47422d8271d1a48280c22f040ab925bc.setContent(html_6e5abf917f41ad79a7971ebcf2d81850);
#
#
#             marker_909c0eccf89da9c9e89ed82133489eef.bindPopup(popup_47422d8271d1a48280c22f040ab925bc)
#             ;
#
#
#
#
#         var marker_f3fb227d8219f5733371fbc91c10666e = L.marker(
#             [40.86886, -73.84915],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#
#             var popup_e44bcac4dba1fdbc6325098996a22993 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_a098fed03d1e1db1c23aa2b0790a147f = $(`&lt;div id=&quot;html_a098fed03d1e1db1c23aa2b0790a147f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_e44bcac4dba1fdbc6325098996a22993.setContent(html_a098fed03d1e1db1c23aa2b0790a147f);
#
#
#             marker_f3fb227d8219f5733371fbc91c10666e.bindPopup(popup_e44bcac4dba1fdbc6325098996a22993)
#             ;
#
#
#
#
#         var marker_ce0bac70303cffb264fa36038e9245ad = L.marker(
#             [40.91306, -73.89389],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_300dfb7a9003102dfe663e6fefa9cc65);
#
#
#             var popup_cb295df1af13652f017c2f22659716a4 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 va
